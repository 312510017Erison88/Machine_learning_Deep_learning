# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 先拿掉轉unicode及標點符號轉換，先看結果
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
import os
# Out:
# cuda

# %%
SOS_token = 0
EOS_token = 1
MAX_LENGTH = 45

# %%
class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# %%
# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.strip())
    # 標點符號前加空格
    s = re.sub(r"([.!?])", r" \1", s)
    return s

# %%
import re
def custom_tokenizer(text):
  tokens = re.findall(r'\b\w+\b|[，、「 」『 』。？：；]', text)
  output = ''
  # print(tokens)
  for i in range(len(tokens)):
    if(tokens[i]!=" "):
      output += tokens[i]
    if i != len(tokens)-1 and tokens[i] != " ":
      output += ' '
  return output

sentence_test = 'm7-kuan2-si7 o5-a2-tsian1 ，'
tokens = custom_tokenizer(sentence_test)
print(tokens)
print(tokens[0])


def zh_custom_tokenizer(sentence):
  tokens = list(sentence)
  alphabet_set = set('abcdefghijklmnopqrstuvwxyzABCDEFGIJKLMNOPQRSTUVWXYZ')
  english = ''
  output_list = []
  cnt = 0
  output = ''
  for i in range(len(tokens)):
    if tokens[i] in alphabet_set:
      english += tokens[i]
      cnt +=1
    else:
      if cnt !=0:
        output_list.append(english)
      if tokens[i] != " ":
        output_list.append(tokens[i])
      cnt = 0
      english = ""
  # print(output_list)
  for j in range(len(output_list)):
    output += output_list[j]
    if j != len(output_list)-1:
      output += ' '
  return output

print(zh_custom_tokenizer("毋管是 蚵仔煎 ，"))
test = tokens.split(' ')
character_to_remove = ''

# 使用列表解析创建新列表，排除特定字符
new_list = [item for item in test if item != character_to_remove]


print(test)
print(new_list)
# Out:
# m7 kuan2 si7 o5 a2 tsian1 ，
# m
# 毋 管 是 蚵 仔 煎 ，
# ['m7', 'kuan2', 'si7', 'o5', 'a2', 'tsian1', '，']
# ['m7', 'kuan2', 'si7', 'o5', 'a2', 'tsian1', '，']

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Update the file path
    file_path = '/content/drive/MyDrive/作業3/tl-zh.txt'

    # Use the updated file path
    lines = open(file_path, encoding='utf-8').read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    # print(pairs[0][0])
    for i in range(len(pairs)):
      pairs[i][0] = custom_tokenizer(pairs[i][0])
      pairs[i][1] = zh_custom_tokenizer(pairs[i][1])
    # print(pairs[0][0])

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
def filterPair(p):
#保留長度條件即可
    p0 = p[0].split(' ')
    character_to_remove = ''

    new_list0 = [item for item in p0 if item != character_to_remove]

    p1 = p[1].split(' ')
    new_list1 = [item for item in p1 if item != character_to_remove]

    return len(new_list0) < MAX_LENGTH and \
        len(new_list1) < MAX_LENGTH

# %%
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)

    # Add the '<unknown>' token to the vocabulary
    input_lang.addWord('<unknown>')

    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    # for i in pairs:
    #     print(list(i))
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = prepareData('tl','zh' , True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 63469 sentence pairs
# Trimmed to 63469 sentence pairs
# Counting words...
# Counted words:
# zh 4454
# tl 2650
# ['跟 隨 當 年 鄭 成 功 的 跤 步 ，', 'kun1 sui5 tong1 ni5 tenn7 sing5 kong1 e5 kha1 poo7 ，']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))
        output, hidden = self.gru(embedded)
        return output, hidden

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.embedding(input)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        return output, hidden

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.Wa = nn.Linear(hidden_size, hidden_size)
        self.Ua = nn.Linear(hidden_size, hidden_size)
        self.Va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
        scores = scores.squeeze(2).unsqueeze(1)

        weights = F.softmax(scores, dim=-1)
        context = torch.bmm(weights, keys)

        return context, weights

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1):
        super(AttnDecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        attentions = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden, attn_weights = self.forward_step(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_outputs.append(decoder_output)
            attentions.append(attn_weights)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        attentions = torch.cat(attentions, dim=1)

        return decoder_outputs, decoder_hidden, attentions


    def forward_step(self, input, hidden, encoder_outputs):
        embedded =  self.dropout(self.embedding(input))

        query = hidden.permute(1, 0, 2)
        context, attn_weights = self.attention(query, encoder_outputs)
        input_gru = torch.cat((embedded, context), dim=2)

        output, hidden = self.gru(input_gru, hidden)
        output = self.out(output)

        return output, hidden, attn_weights

def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

def get_dataloader(batch_size):
    input_lang, output_lang, pairs = prepareData('tl', 'zh', True)

    n = len(pairs)
    input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
    target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

    for idx, (inp, tgt) in enumerate(pairs):
        inp_ids = indexesFromSentence(input_lang, inp)
        tgt_ids = indexesFromSentence(output_lang, tgt)
        inp_ids.append(EOS_token)
        tgt_ids.append(EOS_token)
        input_ids[idx, :len(inp_ids)] = inp_ids
        target_ids[idx, :len(tgt_ids)] = tgt_ids
    print(input_ids)
    print(target_ids)
    train_data = TensorDataset(torch.LongTensor(input_ids).to(device),
                               torch.LongTensor(target_ids).to(device))

    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    return input_lang, output_lang, train_dataloader

def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

    total_loss = 0
    for data in dataloader:
        input_tensor, target_tensor = data

        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

        loss = criterion(
            decoder_outputs.view(-1, decoder_outputs.size(-1)),
            target_tensor.view(-1)
        )
        loss.backward()

        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
print(pairs[75])
# Out:
# ['日 子 柄 無 好 過 ，', 'jit8 tsi2 ping3 bo5 ho2 kue3 ，']

# %% [markdown]
# #### Training loop

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def evaluate_accuracy(encoder, decoder, dataloader, input_lang, output_lang):
    total_correct = 0
    total_words = 0

    with torch.no_grad():
        for data in dataloader:
            input_tensor, target_tensor = data

            encoder_outputs, encoder_hidden = encoder(input_tensor)
            decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

            _, topi = decoder_outputs.topk(1)
            correct = topi.squeeze() == target_tensor.view(-1)

            total_correct += correct.sum().item()
            total_words += correct.numel()

    accuracy = total_correct / total_words
    return accuracy

def evaluate_and_print_accuracy(encoder, decoder, train_dataloader, val_dataloader, input_lang, output_lang):
    train_accuracy = evaluate_accuracy(encoder, decoder, train_dataloader, input_lang, output_lang)
    val_accuracy = evaluate_accuracy(encoder, decoder, val_dataloader, input_lang, output_lang)

    print(f'Train Accuracy: {train_accuracy * 100:.2f}%')
    print(f'Validation Accuracy: {val_accuracy * 100:.2f}%')

def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

hidden_size = 256
batch_size = 64
n_epoch = 10

input_lang, output_lang, train_dataloader = get_dataloader(batch_size)
# print(input_lang[0])
# print(output_lang[0])
encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

train(train_dataloader, encoder, decoder, n_epochs=n_epoch, learning_rate=0.005, print_every=5, plot_every=5)

encoder.eval()
decoder.eval()
evaluateRandomly(encoder, decoder)
# Out:
# Reading lines...
# Read 63469 sentence pairs
# Trimmed to 63469 sentence pairs
# Counting words...
# Counted words:
# zh 4454
# tl 2650
# [[   3    4    5 ...    0    0    0]
#  [  15    6   16 ...    0    0    0]
#  [   3    4    5 ...    0    0    0]
#  ...
#  [ 592  562  595 ...    0    0    0]
#  [ 432   87 1279 ...    0    0    0]
#  [ 221    7  155 ...    0    0    0]]
# [[  2   3   4 ...   0   0   0]
#  [ 14   5  15 ...   0   0   0]
#  [  2   3   4 ...   0   0   0]
#  ...
#  [294 502 526 ...   0   0   0]
#  [396  61 662 ...   0   0   0]
#  [ 93   6 152 ...   0   0   0]]
# 7m 37s (- 15m 14s) (5 33%) 1.0098
# 15m 10s (- 7m 35s) (10 66%) 1.3690
# 22m 37s (- 0m 0s) (15 100%) 1.3556
# > 就 按 呢 日 籍 教 授 報 警 控 告 對 方 傷 害 。
# = tsu7 an2 ne1 jit8 tsik8 kau3 siu7 po3 king2 khong3 ko3 tui3 hong1 siong1 hai7 。
# < SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# > 早 期 就 是 火 炭 窯 產 業 的 大 本 營 ，
# = tsa2 ki5 tioh8 si7 hue2 thuann3 io5 san2 giap8 e5 tai7 pun2 iann5 ，
# < SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# > 不 過 員 工 趕 緊 出 面 否 認 ，
# = put4 ko3 uan5 kang1 kuann2 kin2 tshut4 bin7 honn2 jin7 ，
# < Talbott gua2 tang7 ， <EOS>
#
# > 業 者 黏 的 若 準 是 原 木 貼 皮 呢 ？
# = giap8 tsia2 liam5 e5 na7 tsun2 si7 guan5 bok8 tah4 phue5 ne1 ？
# < SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# > 美 國 佇 舊 年 二 月 到 五 月 ，
# = bi2 kok4 ti7 ku7 ni5 ji7 gueh8 kau3 goo7 gueh8 ，
# < tan7 su7 Arnold khiok4 ， <EOS>
#
# > 疑 似 發 生 氣 爆 的 這 个 三 層 樓 廠 房 ，
# = gi5 su7 huat4 sing1 khi3 pok8 e5 tsit4 e5 sann1 tsan3 lau5 tshiunn2 pang5 ，
# < Arnold tship4 tshiong2 tship4 uann3 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1 uainn1
#
# > 發 生 轎 車 落 海 意 外 ，
# = huat4 sing1 kiau7 tshia1 loh8 hai2 i3 gua7 ，
# < SOS tsia1 kiong2 tiok8 khit8 liam2 sai3 CPR 。 <EOS>
#
# > 保 育 中 心 面 對 寒 流 的 侵 襲 ，
# = po2 iok8 tiong1 sim1 bin7 tui3 han5 liu5 e5 tshim1 sip8 ，
# < tshiann2 tshiann2 tshiann2 ， <EOS>
#
# > 最 近 加 上 油 價 起 價 ，
# = tsue3 kin7 ka1 siang7 iu5 ke3 khi2 ke3 ，
# < SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS
#
# > 騎 著 車 齡 三 十 年 的 Vespa ，
# = khia5 tioh8 tshia1 ling5 sann1 tsap8 ni5 e5 Vespa ，
# < SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS SOS

# %%
input_lang.name
# Out:
# 'zh'

# %%
import pandas as pd
import torch


def indexesFromSentence_testdata(lang, sentence):
    return [lang.word2index.get(char, 0) for char in sentence]

def tensorFromSentence_testdata(lang, sentence):
    indexes = indexesFromSentence_testdata(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def evaluate_testdata(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_tensor = tensorFromSentence_testdata(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                # decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
        # Join the predicted words with a hyphen ("-")
        decoded_sentence = '-'.join(decoded_words)
    return decoded_words, decoder_attn

def predict_and_write_csv(encoder, decoder, test_data, input_lang, output_lang, output_file='submission.csv'):
    # Create an empty list to store predictions
    predictions = []

    # Iterate through the test data
    for idx, sentence in zip(test_data['id'], test_data['txt']):
        # Perform any necessary preprocessing on the test sentence
        preprocessed_sentence = normalizeString(sentence)
        preprocessed_sentence = zh_custom_tokenizer(preprocessed_sentence)
        # print(preprocessed_sentence)
        # print('\n')

        # Use the evaluate function to get predictions
        output_words, _ = evaluate_testdata(encoder, decoder, preprocessed_sentence, input_lang, output_lang)
        print(output_words)
        print('\n')
        # Join the predicted words to form the output sentence
        new_output_words = []
        check_list = {'，','、','「','」','『', '』','。','？','：','；'}
        for i in range(len(output_words)):
          if(output_words[i]!=''):
            if(i != len(output_words)-1):
              new_output_words.append(output_words[i])
              new_output_words.append('-')
            elif(output_words[i] in check_list):
              new_output_words.pop()
              new_output_words.append(output_words[i])

        output_sentence = ''.join(new_output_words)
        print(preprocessed_sentence)
        print(new_output_words)
        print('\n')
        print(output_sentence)
        print('\n')

        # Append the prediction to the list if it's not just special tokens
        if output_sentence.strip() != '<EOS>' and output_sentence.strip() != 'SOS':
            predictions.append({'id': idx, 'txt': output_sentence})
    print(predictions[0])
    # Create a DataFrame from the predictions list
    predictions_df = pd.DataFrame(predictions)

    # Save the DataFrame to a CSV file
    predictions_df.to_csv(output_file, index=False)

# You should replace 'test_data' with the actual variable containing your test data
test_data = pd.read_csv('/content/drive/MyDrive/作業3/translation_data/test-ZH-nospace.csv')
encoder.eval()
decoder.eval()
# Call the function to predict and write to CSV

predict_and_write_csv(encoder, decoder, test_data, input_lang, output_lang)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#
#
# 規 台 車 四 輪 向 天 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 這 是 佇 臺 中 非 常 知 名 的 護 國 清 涼 寺 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['u7', 'tshuan1', 'e5', 'gu5', 'bah4', 'tsang3', '，']
#
#
# 有 兩 隻 臺 灣 烏 熊 ，
# ['u7', '-', 'tshuan1', '-', 'e5', '-', 'gu5', '-', 'bah4', '-', 'tsang3', '，']
#
#
# u7-tshuan1-e5-gu5-bah4-tsang3，
#
#
# ['tuan3', 'e5', 'tsit8', 'lok4', 'si1', '，']
#
#
# 十 一 歲 的 姓 王 查 某 囡 仔 ，
# ['tuan3', '-', 'e5', '-', 'tsit8', '-', 'lok4', '-', 'si1', '，']
#
#
# tuan3-e5-tsit8-lok4-si1，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 立 暝 後 雷 公 雨 無 停 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['bing5', 'hian2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2']
#
#
# 行 到 偏 僻 暗 巷 仔 了 後 ，
# ['bing5', '-', 'hian2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-']
#
#
# bing5-hian2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-
#
#
# ['sam1', 'lip8', 'sin1', 'bun5', 'tai5']
#
#
# 三 立 新 聞 台
# ['sam1', '-', 'lip8', '-', 'sin1', '-', 'bun5', '-']
#
#
# sam1-lip8-sin1-bun5-
#
#
# ['tsit8', 'sut4', '，']
#
#
# 六 月 六 號 下 晡 發 生 一 起 意 外 ，
# ['tsit8', '-', 'sut4', '，']
#
#
# tsit8-sut4，
#
#
# ['sam1', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7', 'kin7']
#
#
# 造 成 當 時 拄 佇 進 行 電 信 工 程 的 兩 名 工 人 ，
# ['sam1', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-', 'kin7', '-']
#
#
# sam1-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-kin7-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 發 生 火 燒 機 車 意 外 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 聯 勤 司 令 部 拄 加 緊 採 購 作 業 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 警 方 將 被 害 人 救 出 時 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['tsong2', 'sng3', 'nge7', 'sng3', 'hueh4', 'bin2', 'hiang1', 'king2', '，']
#
#
# 補 習 班 上 百 名 學 童 內 底 ，
# ['tsong2', '-', 'sng3', '-', 'nge7', '-', 'sng3', '-', 'hueh4', '-', 'bin2', '-', 'hiang1', '-', 'king2', '，']
#
#
# tsong2-sng3-nge7-sng3-hueh4-bin2-hiang1-king2，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 頷 仔 頸 被 升 降 梯 和 天 篷 斬 斷 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['hoo1', 'iok8', 'e5', 'bin5', 'tsiong3', '，']
#
#
# 目 種 兼 細 成 做 糖 尿 病 併 發 症 的 頭 ，
# ['hoo1', '-', 'iok8', '-', 'e5', '-', 'bin5', '-', 'tsiong3', '，']
#
#
# hoo1-iok8-e5-bin5-tsiong3，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 自 由 時 報 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 車 禍 發 生 佇 臺 灣 時 間 十 八 號 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['Stephen', 'kiu2', 'tshai3', 'gan7', 'lui7', 'tsue7', 'e5', 'tshiap4', '，']
#
#
# 煞 橫 霸 的 強 硬 徵 收 農 地 ，
# ['Stephen', '-', 'kiu2', '-', 'tshai3', '-', 'gan7', '-', 'lui7', '-', 'tsue7', '-', 'e5', '-', 'tshiap4', '，']
#
#
# Stephen-kiu2-tshai3-gan7-lui7-tsue7-e5-tshiap4，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 講 出 伊 內 心 的 想 法 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['ko1', 'hiong5', 'tshi7', 'tiunn2', '，']
#
#
# 高 等 法 院 的 發 言 人 解 釋 ，
# ['ko1', '-', 'hiong5', '-', 'tshi7', '-', 'tiunn2', '，']
#
#
# ko1-hiong5-tshi7-tiunn2，
#
#
# ['ji5', 'tshiann2', 'thiam1', '，']
#
#
# 臺 東 這 馬 欠 缺 肉 豬 欠 甲 真 兇 ，
# ['ji5', '-', 'tshiann2', '-', 'thiam1', '，']
#
#
# ji5-tshiann2-thiam1，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 創 下 二 十 三 個 月 以 來 的 新 懸 價 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['khiau2', 'khi3', '，']
#
#
# 雖 然 佇 罐 亞 軍 比 賽 失 利 ，
# ['khiau2', '-', 'khi3', '，']
#
#
# khiau2-khi3，
#
#
# ['it4', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2']
#
#
# 逐 家 攏 希 望 童 玩 節 繼 續 辦 落 去 ，
# ['it4', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-']
#
#
# it4-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 毋 過 糕 仔 餅 的 原 物 料 包 括 牛 奶 粉 、 奶 油 、
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['iau2', 'u7', 'tioh8', 'huah8', 'Williamsport', 'e5', 'bin5', 'tsiong3', 'gai7', '，']
#
#
# 這 爿 是 沙 埔 浮 現 ，
# ['iau2', '-', 'u7', '-', 'tioh8', '-', 'huah8', '-', 'Williamsport', '-', 'e5', '-', 'bin5', '-', 'tsiong3', '-', 'gai7', '，']
#
#
# iau2-u7-tioh8-huah8-Williamsport-e5-bin5-tsiong3-gai7，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 加 水 站 廢 水 閣 回 收 節 約 愛 地 球
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['suan1', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2']
#
#
# 感 覺 真 毋 甘 得 ，
# ['suan1', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-']
#
#
# suan1-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-
#
#
# ['tsong2', 'sng3', 'sng3', '，']
#
#
# 隊 員 盧 俊 宏 用 一 點 外 鐘 的 時 間 ，
# ['tsong2', '-', 'sng3', '-', 'sng3', '，']
#
#
# tsong2-sng3-sng3，
#
#
# ['sio1', 'tsenn1', 'sam1', 'lip8', 'ui2']
#
#
# 對 便 所 邊 的 邊 角 挕 捒 ，
# ['sio1', '-', 'tsenn1', '-', 'sam1', '-', 'lip8', '-']
#
#
# sio1-tsenn1-sam1-lip8-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 四 百 四 十 五 匹 馬 坐 飛 機 創 下 空 運 紀 錄
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['guan5', 'e5', 'si7', 'long5', 'su7', 'kiann7', '，']
#
#
# 伊 利 用 當 地 生 產 的 薑 ，
# ['guan5', '-', 'e5', '-', 'si7', '-', 'long5', '-', 'su7', '-', 'kiann7', '，']
#
#
# guan5-e5-si7-long5-su7-kiann7，
#
#
# ['kiu2', 'kok4', 'kok4', 'tse3', 'tsok4', '，']
#
#
# 已 經 佇 二 十 五 號 倒 轉 中 國 ，
# ['kiu2', '-', 'kok4', '-', 'kok4', '-', 'tse3', '-', 'tsok4', '，']
#
#
# kiu2-kok4-kok4-tse3-tsok4，
#
#
# ['Stephen', 'Young', 'sing5', 'tiong2', '」', '，']
#
#
# 前 臺 北 市 新 建 工 程 處 長 黃 錫 薰 ，
# ['Stephen', '-', 'Young', '-', 'sing5', '-', 'tiong2', '-', '」', '，']
#
#
# Stephen-Young-sing5-tiong2-」，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 位 佇 嘉 義 縣 太 保 鄉 的 臺 塑 南 亞 塑 膠 廠 發 生 火 燒 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['iau2', 'u7', 'tsiam5', 'u7', 'png2', 'kiu2', 'lian1', '，']
#
#
# 其 中 有 六 人 是 印 尼 籍 的 外 勞 ，
# ['iau2', '-', 'u7', '-', 'tsiam5', '-', 'u7', '-', 'png2', '-', 'kiu2', '-', 'lian1', '，']
#
#
# iau2-u7-tsiam5-u7-png2-kiu2-lian1，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 民 視 新 聞 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 民 視 新 聞 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['Beauchamp', '，']
#
#
# 甚 至 佇 二 空 一 空 年 猶 推 出 了 郵 購 目 錄 ，
# ['Beauchamp', '，']
#
#
# Beauchamp，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 佇 二 十 號 公 佈 財 政 束 絚 計 畫 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['liu3', 'kiu2', 'huah8', 'the2', 'tship4', '，']
#
#
# 欣 賞 暗 晡 仔 時 陣 的 西 照 日 ，
# ['liu3', '-', 'kiu2', '-', 'huah8', '-', 'the2', '-', 'tship4', '，']
#
#
# liu3-kiu2-huah8-the2-tship4，
#
#
# ['tsit8', 'ting7', 'it4', 'kiu2', 'it4', 'kiu2', 'lu5', 'tsong2', 'thong2', '，']
#
#
# 一 黃 一 紅 象 徵 平 安 祝 福 ，
# ['tsit8', '-', 'ting7', '-', 'it4', '-', 'kiu2', '-', 'it4', '-', 'kiu2', '-', 'lu5', '-', 'tsong2', '-', 'thong2', '，']
#
#
# tsit8-ting7-it4-kiu2-it4-kiu2-lu5-tsong2-thong2，
#
#
# ['Clinton', 'iau3', 'guan5', 'it4', 'pai2', 'huah8', '，']
#
#
# 臺 中 市 長 胡 志 強 召 募 志 工 的 短 片 ，
# ['Clinton', '-', 'iau3', '-', 'guan5', '-', 'it4', '-', 'pai2', '-', 'huah8', '，']
#
#
# Clinton-iau3-guan5-it4-pai2-huah8，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 民 視 新 聞 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['kiu2', 'kiu2', 'kiu2', 'kiu2', 'ni5', 'tship4', 'tiunn2', 'ni5', 'mui2', 'ni5', 'tship4', '，']
#
#
# 每 年 攏 會 創 造 可 觀 的 外 銷 營 收 ，
# ['kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'ni5', '-', 'tship4', '-', 'tiunn2', '-', 'ni5', '-', 'mui2', '-', 'ni5', '-', 'tship4', '，']
#
#
# kiu2-kiu2-kiu2-kiu2-ni5-tship4-tiunn2-ni5-mui2-ni5-tship4，
#
#
# ['Yankee', 'sua3', 'Williamsport', 'gue7', 'tsia2', '，']
#
#
# 李 先 生 提 出 一 疊 罰 單 都 厚 到 十 公 分 ，
# ['Yankee', '-', 'sua3', '-', 'Williamsport', '-', 'gue7', '-', 'tsia2', '，']
#
#
# Yankee-sua3-Williamsport-gue7-tsia2，
#
#
# ['it4', 'kiu2', 'lu5', 'tsue7', '，']
#
#
# 至 於 社 區 為 何 激 烈 反 應 愛 問 對 方 ，
# ['it4', '-', 'kiu2', '-', 'lu5', '-', 'tsue7', '，']
#
#
# it4-kiu2-lu5-tsue7，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 佇 紅 茶 的 故 鄉 日 月 潭 邊 仔 進 行 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 畜 產 廢 棄 物 處 理 佮 污 染 防 治 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 雖 然 開 了 袂 少 錢 買 物 件 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['te2', 'te2', 'siang5', '。']
#
#
# 就 按 呢 美 國 希 望 盡 快 恢 復 雙 爿 對 話 。
# ['te2', '-', 'te2', '-', 'siang5', '。']
#
#
# te2-te2-siang5。
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 臺 灣 的 抐 桮 保 育 工 作 有 成 果 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 遭 開 銃 拍 著 正 胸 坎 的 女 店 員 陳 品 蓉 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['bin5', 'tsiong3', 'hainn1', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'sam1', 'kiap4', '，']
#
#
# 粟 仔 的 生 產 量 佔 了 全 臺 灣 三 分 之 一 ，
# ['bin5', '-', 'tsiong3', '-', 'hainn1', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'sam1', '-', 'kiap4', '，']
#
#
# bin5-tsiong3-hainn1-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-sam1-kiap4，
#
#
# ['tng5', 'hue3', 'e5', 'khip4', 'in2', 'lok4', '，']
#
#
# 四 十 一 歲 姓 張 查 埔 五 年 前 來 金 門 做 散 工 ，
# ['tng5', '-', 'hue3', '-', 'e5', '-', 'khip4', '-', 'in2', '-', 'lok4', '，']
#
#
# tng5-hue3-e5-khip4-in2-lok4，
#
#
# ['ping7', 'tshiann2', '，']
#
#
# 今 年 比 舊 年 同 期 加 了 一 萬 箱 雞 卵 ，
# ['ping7', '-', 'tshiann2', '，']
#
#
# ping7-tshiann2，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 彰 化 基 督 教 醫 院 副 院 長 周 賢 彰 講 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 欲 倚 六 十 二 萬 人 支 持 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['it4', 'pai2', 'tiok8', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5', 'ko5']
#
#
# 開 車 佮 路 過 的 民 眾 轎 車 對 挵 發 袂 撞 ，
# ['it4', '-', 'pai2', '-', 'tiok8', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-', 'ko5', '-']
#
#
# it4-pai2-tiok8-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-ko5-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 不 斷 佇 美 國 國 會 遊 說 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 空 軍 司 令 雷 玉 其 親 自 出 面 說 明 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 坐 公 務 車 予 司 機 加 班 前 往 婚 禮 會 場 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 民 視 新 聞 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 其 中 猶 有 超 級 罕 見 的 頂 級 牛 樟 菇 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 前 往 高 雄 市 的 三 鳳 中 街 佮 大 賣 場 檢 查 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 民 視 新 聞 報 導
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 記 者 親 身 體 驗 嘛 發 現 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 江 國 慶 老 母 得 知 消 息 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['kiu2', 'kiu2', 'pai2', 'tsun7', 'sng3', '，']
#
#
# 越 南 今 年 的 生 相 有 淡 薄 奇 怪 ，
# ['kiu2', '-', 'kiu2', '-', 'pai2', '-', 'tsun7', '-', 'sng3', '，']
#
#
# kiu2-kiu2-pai2-tsun7-sng3，
#
#
# ...
#
#
# 除 了 會 曉 講 臺 語 嘛 愛 捌 英 文 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['tsiunn2', 'i2', 'Williamsport', 'po3', 'to7', 'tsue7', 'la2', 'song2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', '」', '，']
#
#
# 毋 過 小 學 生 的 誠 實 佮 古 錐 ，
# ['tsiunn2', '-', 'i2', '-', 'Williamsport', '-', 'po3', '-', 'to7', '-', 'tsue7', '-', 'la2', '-', 'song2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', '」', '，']
#
#
# tsiunn2-i2-Williamsport-po3-to7-tsue7-la2-song2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-」，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 這 馬 會 使 使 用 悠 遊 卡 付 款 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 擔 任 農 曆 新 春 的 祈 福 人 員 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['tng5', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2']
#
#
# 規 家 六 口 蹛 佇 五 坪 的 厝 。
# ['tng5', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-']
#
#
# tng5-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-
#
#
# ['tsit4', 'tsap8', 'it4', 'kiu2', 'lian1', '，']
#
#
# 臺 鐵 佇 高 雄 的 路 段 傳 出 意 外 ，
# ['tsit4', '-', 'tsap8', '-', 'it4', '-', 'kiu2', '-', 'lian1', '，']
#
#
# tsit4-tsap8-it4-kiu2-lian1，
#
#
# ['tioh4', 'tshe1', '1nih4', 'jiong7', 'tioh4', 'tshe1', '1si1', '1mih4', 'Somalia', 'gue7', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4', 'hmh4']
#
#
# 愛 看 飛 機 起 降 的 軍 事 迷 講 ，
# ['tioh4', '-', 'tshe1', '-', '1nih4', '-', 'jiong7', '-', 'tioh4', '-', 'tshe1', '-', '1si1', '-', '1mih4', '-', 'Somalia', '-', 'gue7', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-', 'hmh4', '-']
#
#
# tioh4-tshe1-1nih4-jiong7-tioh4-tshe1-1si1-1mih4-Somalia-gue7-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-hmh4-
#
#
# ['Timothy', 'Geithner', 'pai5', 'phin1', '。']
#
#
# 嘛 有 網 友 支 持 拆 捒 的 行 動 。
# ['Timothy', '-', 'Geithner', '-', 'pai5', '-', 'phin1', '。']
#
#
# Timothy-Geithner-pai5-phin1。
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 準 備 予 獲 勝 的 民 眾 紮 轉 去 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 慢 慢 的 筆 劃 筆 劃 寫 出 「 福 」 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['sam1', 'lip8', 'ui2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2', 'kiu2']
#
#
# 雖 然 每 擺 黃 柑 李 的 花 期 ，
# ['sam1', '-', 'lip8', '-', 'ui2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-', 'kiu2', '-']
#
#
# sam1-lip8-ui2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-kiu2-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 這 位 手 工 西 裝 老 師 傅 顛 覆 傳 統 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 當 做 車 路 轎 車 開 上 鐵 枝 路 火 車 追 挵
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['ji5', 'tshiann2', 'bing5', 'hian2', '，']
#
#
# 這 馬 橄 欖 球 納 入 亞 運 佮 奧 運 項 目 ，
# ['ji5', '-', 'tshiann2', '-', 'bing5', '-', 'hian2', '，']
#
#
# ji5-tshiann2-bing5-hian2，
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 這 隻 大 摸 的 美 國 大 龍 蝦 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 結 果 連 紲 三 間 的 豬 肉 擔 仔 ，
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['lim5', 'e5', 'hong1', 'thai1', '，']
#
#
# 這 棟 三 樓 透 天 厝 的 二 樓 ，
# ['lim5', '-', 'e5', '-', 'hong1', '-', 'thai1', '，']
#
#
# lim5-e5-hong1-thai1，
#
#
# ['iau2', 'buah4', 'tshiann2', '。']
#
#
# 線 頂 指 導 家 屬 進 行 搶 救 。
# ['iau2', '-', 'buah4', '-', 'tshiann2', '。']
#
#
# iau2-buah4-tshiann2。
#
#
# ['sam1', 'pai7', 'Clinton', '。']
#
#
# 經 過 高 等 法 院 臺 中 分 院 的 更 一 審 ，
# ['sam1', '-', 'pai7', '-', 'Clinton', '。']
#
#
# sam1-pai7-Clinton。
#
#
# ['SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS', 'SOS']
#
#
# 脂 肪 含 量 懸 而 且 較 芳 純 。
# ['SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-', 'SOS', '-']
#
#
# SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-SOS-
#
#
# ['tsit8', 'tshat4', '。']
#
#
# 一 串 一 串 的 弓 蕉 落 規 塗 跤 。
# ['tsit8', '-', 'tshat4', '。']
#
#
# tsit8-tshat4。
#
#
# ['iau2', 'hik8', '。']
#
#
# 毋 知 影 按 怎 剝 開 分 離 。
# ['iau2', '-', 'hik8', '。']
#
#
# iau2-hik8。
#
#
# {'id': 1, 'txt': 'sam1-kin7-tshiann2，'}
